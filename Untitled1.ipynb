# %%
# Out:
#   File "<ipython-input-3-9ad028046cd4>", line 1
#     ${\displaystyle f(x)={\frac {1}{\sigma {\sqrt {2\pi }}}}e^ {-{\frac {1}{2}}\left({\frac {x-\mu }{\sigma }}\right)^{2}}}$
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ${\displaystyle f(x)={\frac {1}{\sigma {\sqrt {2\pi }}}}e^ {-{\frac {1}{2}}\left({\frac {x-\mu }{\sigma }}\right)^{2}}}$
#
# Заглавная|Строчная|Название
# --|--|--
# A|α|Альфа
# B|β|Бета
# Γ|γ|Гамма
# Δ|δ|Дельта
# Ε|ϵ|Эпсилон
# Z|ζ|Зета
# H|η|Эта
# Θ|θ,ϑ|Тета
# I|ι|Йота
# K|κ,ϰ|Каппа
# Λ|λ|Лямбда
# M|μ|Мю
# N|ν|Нью
# Ξ|ξ|Кси
# O|o|О
# Π|π,ϖ|Пи
# P|ρ,ϱ|Ро
# Σ|σ,ς|Сигма
# T|τ|Тау
# Υ|υ|Упсилон
# Φ|ϕ,φ|Пфи
# X|χ|Чи
# Ψ|ψ|Пси
# Ω|ω|Омега
